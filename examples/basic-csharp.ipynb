// %% [markdown]
// # Basic C# (.ipynb format)
//
// This notebook demonstrates basic C# operations in Jupyter `.ipynb` format with `.NET Interactive`.
// It is the Jupyter-format equivalent of `hello-world.dib`.

// %%
Console.WriteLine("Hello from Polyglot Notebooks!");
// Out:
// Hello from Polyglot Notebooks!

// %% [markdown]
// ## Variables and String Interpolation

// %%
var name = "Polyglot Notebooks";
var version = 1;
var active = true;

Console.WriteLine($"Name: {name}");
Console.WriteLine($"Version: {version}");
Console.WriteLine($"Active: {active}");
// Out:
// Name: Polyglot Notebooks
// Version: 1
// Active: True

// %% [markdown]
// ## Basic Math

// %%
int[] numbers = { 1, 2, 3, 4, 5 };
int sum = numbers.Sum();
int product = numbers.Aggregate(1, (acc, n) => acc * n);

Console.WriteLine($"Sum: {sum}");
Console.WriteLine($"Product: {product}");
Console.WriteLine($"Square root of 144: {Math.Sqrt(144)}");
// Out:
// Sum: 15
// Product: 50
// Square root of 144: 12

// %% [markdown]
// ## LINQ

// %%
var evens = Enumerable.Range(1, 10).Where(n => n % 2 == 0);
Console.WriteLine($"Even numbers: {string.Join(", ", evens)}");
// Out:
// Even numbers: 2, 4, 6, 8, 10
